# %%
import googlemaps
import folium
import pandas as pd
import numpy as np
import heapq
from haversine import haversine #거리구하기
from sklearn.preprocessing import minmax_scale #정규화


##data 불러오기
total_df = pd.read_csv("all_df.csv", encoding = "EUC-KR" )
df = total_df.rename(index=str, columns={"Unnamed: 0" : "ID"})
df = df.drop(columns = ['경유여부','거리'])
print(len(df))
df
# Out:
# 2090
#         ID    point_ID  밝기  총밝기    분류                          명칭         위도  \
# 0        0     Point_0   5  135   보안등                     역삼1동833  37.493349
# 1        1     Point_1   5  135   보안등                     역삼1동833  37.493349
# 2        2     Point_2   5  135   보안등                     역삼1동833  37.493349
# 3        3     Point_3   5  135   보안등                     역삼1동833  37.493349
# 4        4     Point_4   5  135   보안등                     역삼1동833  37.493349
# 5        5     Point_5   5   10   보안등                  역삼1동832-25  37.492834
# 6        6     Point_6   5   50   보안등                  역삼1동832-27  37.492632
# 7        7     Point_7   5   50   보안등                  역삼1동832-28  37.492480
# 8        8     Point_8   5   50   보안등                  역삼1동832-28  37.492480
# 9        9     Point_9   5   75   보안등                  역삼1동832-29  37.492343
# 10      10    Point_10   5  125   보안등                  역삼1동832-31  37.492030
# 11      11    Point_11   5  125   보안등                  역삼1동832-31  37.492030
# 12      12    Point_12   5   65   보안등                  역삼1동837-33  37.491576
# 13      13    Point_13   5   40   보안등                  역삼1동837-15  37.491900
# 14      14    Point_14   5   65   보안등                  역삼1동837-16  37.491957
# 15      15    Point_15   5    5   보안등                     역삼1동836  37.491975
# 16      16    Point_16   5   50   보안등                   역삼1동836-1  37.491622
# 17      17    Point_17   5   55   보안등                   역삼1동836-2  37.491662
# 18      18    Point_18   5   50   보안등                  역삼1동836-14  37.491485
# 19      19    Point_19   5   50   보안등                  역삼1동836-15  37.491442
# 20      20    Point_20   5   40   보안등                  역삼1동836-25  37.490908
# 21      21    Point_21   5   40   보안등                   역삼1동840-1  37.491164
# 22      22    Point_22   5   75   보안등                   역삼1동840-3  37.491250
# 23      23    Point_23   5   40   보안등                   역삼1동840-5  37.491322
# 24      24    Point_24   5   40   보안등                   역삼1동840-5  37.491322
# 25      25    Point_25   5   35   보안등                  역삼1동835-51  37.491654
# 26      26    Point_26   5   10   보안등                     역삼1동799  37.491589
# 27      27    Point_27   5   35   보안등                  역삼1동835-52  37.491715
# 28      28    Point_28   5   30   보안등                  역삼1동793-52  37.491942
# 29      29    Point_29   5  130   보안등                  역삼1동835-68  37.492310
# ...    ...         ...  ..  ...   ...                         ...        ...
# 2060  2060  Point_2060  25   55  CCTV                  역삼동 721-28  37.499869
# 2061  2061  Point_2061  25   55  CCTV                  역삼동 725-25  37.500484
# 2062  2062  Point_2062  25   25  CCTV         역삼동 702-1(역삼지하보도 내)  37.502510
# 2063  2063  Point_2063  25   25  CCTV                  역삼동 783-16  37.494971
# 2064  2064  Point_2064  25   50  CCTV                  역삼동 792-38  37.493998
# 2065  2065  Point_2065  25   55  CCTV         역삼동 795-26 (역삼마을마당)  37.492384
# 2066  2066  Point_2066  25   85  CCTV  역삼동 707-42 (한신인터밸리24빌딩 주변)  37.503007
ep = (37.509122, 127.043816) #도착지 37.509122, 127.043816


df = df.append(df.from_dict({'ID' : -1,'point_ID':'Point_SP', '위도':sp[0], '경도':sp[1], '밝기':-l_max
                             , '분류':'출발지', '명칭':'출발지', '총밝기' : -l_max }, orient = 'index').T)

df = df.append(df.from_dict({'ID' : len(df), 'point_ID':'Point_EP', '위도':ep[0], '경도':ep[1], '밝기':l_max
                             , '분류':'도착지', '명칭':'도착지', '총밝기' : l_max}, orient = 'index').T)

df = df.sort_values(by='ID').reset_index(drop=True)
df
# #df['ID'] = df.index.valuesd
# df = df.set_index('ID')

# %%
#총 거리
d_m = haversine(sp, ep, unit='m') # in meters
d_km = haversine(sp, ep,  unit='m')  # in kilometers

#block단위 
# 경유지가 총 3개까지만 가능하니까 3개의 반경으로 나누자. 700 이상인 경우는 api다시 받기 (추후에)
dvd = d_m / 4
print( "단위거리(dvd) : ",  dvd, ", 총거리(d_m) : " , d_m)
# Out:
# 단위거리(dvd) :  175.38377731330854 , 총거리(d_m) :  701.5351092532342

# %% [markdown]
# ## 함수정리
# 1. get_points_in_range : 중심점에서 범위 내 포함되는 점들 검색
# 2. get_gf : G, H 구하기. return 은 F
# 3. get_scaled_f : F scaling

# %%
# 초기화
point = sp
sel_pointID = 'Point_SP'
radius = 100 #반경
closed_list = []
closed_list_id = []
closed_list_seq = []
#goodbye = pd.DataFrame(columns = ['위도', '경도'] )
#반경 내 포함 points 검색
def get_points_in_range(df, point):
    rad = radius
    
    while True :
        res = df [ df.apply( lambda x : haversine(point, [x['위도'], x['경도']] ,  unit='m') , axis = 1  ) < rad ]
        res = res[ ~res['point_ID'].isin(closed_list_id) ] # 1-2 . 이미 선택했던 point들 제외   
        if (len(res) == 0  ) : 
            rad += 10
        else : 
            break
    return res

#가중치 구하기
#1. F구하기 
def get_f( df ):
    g = np.array(df.apply(lambda x : haversine(sp, [x['위도'], x['경도']] ,  unit='m') , axis = 1 )).reshape(-1,1)
    h = np.array(df.apply(lambda x : haversine(ep, [x['위도'], x['경도']] ,  unit='m') , axis = 1 )).reshape(-1,1)  
    return g+h

#2. Scaled_F : 밝기 0~100 에 맞추기
def get_scaled_f(df):
    X_MinMax_scaled = l_max - minmax_scale(df['F'], axis=0, copy=True, feature_range =(0,l_max))
    return X_MinMax_scaled

#3. 밝기 이용한 가중치 추가 W(weight = 4F(거리) + 6L(밝기))
def get_w(df) : 
    w = np.array(df.apply(lambda x : (x['총밝기'] * 45 ) + ( x['scaled_F'] * 100) , axis = 1)).reshape(-1,1)
    w = minmax_scale(w, copy=True, feature_range =(0,l_max))
    return w

# %%
#반경 내 포함 points 검색
def get_points_in_range(df, point):
    rad = radius
    
    while True :
        res = df [ df.apply( lambda x : haversine(point, [x['위도'], x['경도']] ,  unit='m') , axis = 1  ) < rad ]
        res = res[ ~res['point_ID'].isin(closed_list_id) ] # 1-2 . 이미 선택했던 point들 제외   
        if (len(res) == 0  ) : 
            rad += 10
        else : 
            break
    return res

#가중치 구하기
#1. F구하기 
def get_f( df ):
    g = np.array(df.apply(lambda x : haversine(sp, [x['위도'], x['경도']] ,  unit='m') , axis = 1 )).reshape(-1,1)
    h = np.array(df.apply(lambda x : haversine(ep, [x['위도'], x['경도']] ,  unit='m') , axis = 1 )).reshape(-1,1)  
    return g+h

#2. Scaled_F : 밝기 0~100 에 맞추기
def get_scaled_f(df):
    X_MinMax_scaled = 110 - minmax_scale(df['F'], axis=0, copy=True, feature_range =(0,110))
    return X_MinMax_scaled

#3. 밝기 이용한 가중치 추가 W(weight = 4F(거리) + 6L(밝기))
def get_w(df) : 
    w = np.array(df.apply(lambda x : (x['총밝기'] * 40 ) + ( x['scaled_F'] * 80) , axis = 1)).reshape(-1,1)
    return w

# %%
#1. 해당 ID Close List에 추가
n = 0
heapq.heappush(closed_list_id, 'Point_SP' )
heapq.heappush(closed_list_seq, n )
heapq.heappush(closed_list, point)

while( sel_pointID != 'Point_EP' ) : 
    #print("시작포인트 : " , point)
    points = pd.DataFrame()
    points = get_points_in_range(df, point)    #1. 반경 내 속하는 점들 검색
    points['F'] = get_f(points)                #2. F=G+H : F구하기
    points['scaled_F'] = get_scaled_f(points)  #3. F를 밝기에 맞춰 스케일링
    points['W'] = get_w(points)                #4. 최종가중치 구하기
    
    points = points.sort_values('W', ascending = False).reset_index() #5. 정렬

    print(points.loc[0,'point_ID'])
    sel_pointID = points.loc[0,'point_ID']
    point = (points.loc[0,'위도'] , points.loc[0,'경도'])

    #goodbye.append(points.loc[1:,'point_ID'].values)
    heapq.heappush(closed_list_id, sel_pointID)
    heapq.heappush(closed_list_seq, n)
    heapq.heappush(closed_list, ( points.loc[0,'위도'] , points.loc[0,'경도']))
    n+=1
   # print(sel_pointID)
# Out:
# Point_1789
# Point_1379
# Point_1316
# Point_1373
# Point_1372
# Point_1317
# Point_1382
# Point_1381
# Point_1380
# Point_1834
# Point_1503
# Point_1321
# Point_1374
# Point_2072
# Point_1298
# Point_1296
# Point_1378
# Point_1292
# Point_1293
# Point_1295
# Point_1805
# Point_1320
# Point_1437
# Point_1438
# Point_1502
# Point_1318
# Point_1323
# Point_1371
# Point_1322
# Point_1319
# Point_1637
# Point_703
# Point_2023
# Point_1377
# Point_704
# Point_1504
# Point_1445
# Point_1376
# Point_1439
# Point_1951
# Point_469
# Point_1974
# Point_1386
# Point_1387
# Point_1970
# Point_1326
# Point_1297
# Point_1294
# Point_1892
# Point_1722
# Point_200
# Point_278
# Point_279
# Point_168
# Point_173
# Point_172
# Point_2005
# Point_169
# Point_246
# Point_247
# Point_248
# Point_473
# Point_EP

# %%
# 역삼동 중심 = 역삼역 /  좌표 : 37.500742, 127.036891
to_map1 = folium.Map(location= sp, zoom_start=18)
a = closed_list


for n in range(0, len(a)) :
      folium.CircleMarker([a[n][0], a[n][1]], popup= str(closed_list_seq[n]), radius = 3).add_to(to_map1)        

# 구분하기 쉽게 스타팅 지역은 빨간색 마커로 표시        
folium.Marker(sp, popup= 'SP', icon=folium.Icon(color='red')).add_to(to_map1)
folium.Marker(ep, popup= 'EP', icon=folium.Icon(color='black')).add_to(to_map1)
to_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df[df['point_ID'] == 'Point_248' ]
df[df['명칭'].str.contains('목화') ]

#closed_list_id
# Out:
#         ID    point_ID       경도          명칭  밝기   분류       위도 총밝기
# 1717  1795  Point_1795  127.043  GS25 역삼목화점  30  편의점  37.5089  75

# %%
dd = total_df[ total_df['point_ID'].isin(closed_list_id) ].sort_values('총밝기', ascending = False)
dd
# Out:
#       Unnamed: 0    point_ID  거리  밝기  총밝기    분류                      명칭  \
# 246          246   Point_246   0   5  120   보안등              역삼1동 685-2
# 1437        1437  Point_1437   0   5  110   보안등              역삼1동 661-3
# 1834        1834  Point_1834   0  25  110  CCTV              역삼동 655-13
# 1789        1789  Point_1789   0  30  110   편의점               CU 역삼에스원점
# 1323        1323  Point_1323   0   5  105   보안등             역삼1동 655-13
# 1379        1379  Point_1379   0   5  105   보안등             역삼1동 656-12
# 1438        1438  Point_1438   0   5  105   보안등             역삼1동 660-33
# 469          469   Point_469   0   5  100   보안등                역삼1동 663
# 1637        1637  Point_1637   0  30  100   편의점              GS25 역삼충현점
# 1387        1387  Point_1387   0   5  100   보안등             역삼1동 657-23
# 1316        1316  Point_1316   0   5   90   보안등              역삼1동 656-5
# 1317        1317  Point_1317   0   5   85   보안등             역삼1동 657-40
# 1382        1382  Point_1382   0   5   85   보안등                역삼1동 661
# 1381        1381  Point_1381   0   5   85   보안등                역삼1동 661
# 1380        1380  Point_1380   0   5   85   보안등                역삼1동 661
# 1503        1503  Point_1503   0   5   85   보안등              역삼1동 661-1
# 1502        1502  Point_1502   0   5   80   보안등             역삼1동 660-29
# 1373        1373  Point_1373   0   5   80   보안등             역삼1동 656-37
# 169          169   Point_169   0   5   80   보안등             역삼1동 687-12
# 1951        1951  Point_1951   0  25   80  CCTV               역삼동 663-3
# 1321        1321  Point_1321   0   5   80   보안등                역삼1동 656
# 168          168   Point_168   0   5   80   보안등             역삼1동 687-12
# 1372        1372  Point_1372   0   5   80   보안등             역삼1동 656-37
# 172          172   Point_172   0   5   80   보안등              역삼1동 684-4
# 173          173   Point_173   0   5   80   보안등              역삼1동 684-4
# 1974        1974  Point_1974   0  25   75  CCTV               역삼동 665-1
# 1970        1970  Point_1970   0  25   75  CCTV  역삼동 657-27 (참사랑어린이집 앞)
# 1439        1439  Point_1439   0   5   75   보안등             역삼1동 661-12
# 473          473   Point_473   0   5   75   보안등             역삼1동 684-27
# 1320        1320  Point_1320   0   5   70   보안등             역삼1동 660-28
# ...          ...         ...  ..  ..  ...   ...                     ...
# 2072        2072  Point_2072   0  25   65  CCTV               역삼동 661-8
# 1376        1376  Point_1376   0   5   60   보안등             역삼1동 661-15
# 703          703   Point_703   0   5   60   보안등             역삼1동 661-15
# 248          248   Point_248   0   5   55   보안등              역삼1동 684-6
# 279          279   Point_279   0   5   55   보안등              역삼1동 686-1
# 1805        1805  Point_1805   0  30   55   편의점             GS25 강남갤러리점
# 200          200   Point_200   0   5   55   보안등              역삼1동 686-1
# 247          247   Point_247   0   5   55   보안등              역삼1동 684-5
# 278          278   Point_278   0   5   55   보안등              역삼1동 686-1
# 1318        1318  Point_1318   0   5   55   보안등             역삼1동 657-37
# 1326        1326  Point_1326   0   5   50   보안등             역삼1동 657-36
# 1445        1445  Point_1445   0   5   50   보안등             역삼1동 661-26
# 1504        1504  Point_1504   0   5   50   보안등             역삼1동 661-26
# 1322        1322  Point_1322   0   5   50   보안등              역삼1동 656-1
# 1371        1371  Point_1371   0   5   50   보안등              역삼1동 656-3
