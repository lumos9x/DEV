# %%
import shapefile
import json
from pyproj import Proj, transform
import googlemaps
import folium

inProj = Proj(init = 'epsg:5179 ') #korea2000
outProj= Proj(init = 'epsg:4326') #wgs84

# %%
shape = shapefile.Reader("TL_SPRD_MANAGE.shp", encoding = "euc-kr")
feature = shape.shapeRecords()[0]
first = feature.shape.__geo_interface__  
len(shape)
# Out:
# 1845

# %%
# first['type']
# type(first['coordinates'][0])
coord = []
for j in range(49, 60):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
        
        
for j in range(84, 95):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
        
for j in range(119, 130):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
        
for j in range(162, 176):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
        
        
coord
# Out:
# [[37.50259686627172, 127.02537440354597],
#  [37.50284144908216, 127.0261749196054],
#  [37.50301270964507, 127.02673543212374],
#  [37.50311219098833, 127.02706103885035],
#  [37.5031931241506, 127.02732592013159],
#  [37.50333094954667, 127.02777703058763],
#  [37.50345012732482, 127.02816712189686],
#  [37.50345033439874, 127.02816781184323],
#  [37.50105916063711, 127.02611438434687],
#  [37.50173813808296, 127.02669898386996],
#  [37.502048492808235, 127.02696619960001],
#  [37.50221332683842, 127.02710812950896],
#  [37.50272932162395, 127.02755240980473],
#  [37.5034499380361, 127.02816747242068],
#  [37.50345033439874, 127.02816781184323],
#  [37.503958218576464, 127.02860131460223],
#  [37.50036295147544, 127.02645109408468],
#  [37.50060303368364, 127.0272397590849],
#  [37.50075119504084, 127.02772648070405],
#  [37.50079876002991, 127.02788273103494],
#  [37.50098900889989, 127.02850775695431],
#  [37.500995028798535, 127.02858115466246],
# ...

# %%
for j in range(713, 985):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])

# %%
for j in range(518, 700):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
for j in range(194, 201):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])
for j in range(218, 227):
               #len(shape) ) :
    feature = shape.shapeRecords()[j]
    first = feature.shape.__geo_interface__  
    for i in range(0, len(first['coordinates'])):
        li = first['coordinates'][i]
        x,y = transform(inProj,outProj,li[0],li[1])
        coord.append([y,x])

# %%
to_map1 = folium.Map(location= coord[0], zoom_start=18)
a = coord
for n in range(0, len(a)) :
      folium.CircleMarker([a[n][0], a[n][1]], radius = 3).add_to(to_map1)        
to_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
